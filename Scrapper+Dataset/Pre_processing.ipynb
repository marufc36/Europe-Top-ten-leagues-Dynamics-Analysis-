# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("bundesliga_match_data.csv")



df1
# Out:
#            date      home_team  score      away_team
# 0    19-08-2023       Augsburg  4 - 4    M''gladbach
# 1    27-08-2023  Bayern Munich  3 - 1       Augsburg
# 2    02-09-2023       Augsburg  2 - 2         Bochum
# 3    16-09-2023     RB Leipzig  3 - 0       Augsburg
# 4    23-09-2023       Augsburg  2 - 1          Mainz
# ..          ...            ...    ...            ...
# 211  21-10-2023      Wolfsburg  1 - 2     Leverkusen
# 212  28-10-2023       Augsburg  3 - 2      Wolfsburg
# 213  05-11-2023      Wolfsburg  2 - 2  Werder Bremen
# 214  10-11-2023    M''gladbach  4 - 0      Wolfsburg
# 215  25-11-2023      Wolfsburg  ? - ?     RB Leipzig
#
# [216 rows x 4 columns]

# %%
df1[['home_team_score', 'away_team_score']] = df1['score'].str.split(' - ', expand=True)
df1['home_team_score'] = pd.to_numeric(df1['home_team_score'], errors='coerce')
df1['away_team_score'] = pd.to_numeric(df1['away_team_score'], errors='coerce')
df1['home_team_score'] = df1['home_team_score'].fillna(0)
df1['away_team_score'] = df1['away_team_score'].fillna(0)




df1
# Out:
#            date      home_team  score      away_team  home_team_score  \
# 0    19-08-2023       Augsburg  4 - 4    M''gladbach              4.0
# 1    27-08-2023  Bayern Munich  3 - 1       Augsburg              3.0
# 2    02-09-2023       Augsburg  2 - 2         Bochum              2.0
# 3    16-09-2023     RB Leipzig  3 - 0       Augsburg              3.0
# 4    23-09-2023       Augsburg  2 - 1          Mainz              2.0
# ..          ...            ...    ...            ...              ...
# 211  21-10-2023      Wolfsburg  1 - 2     Leverkusen              1.0
# 212  28-10-2023       Augsburg  3 - 2      Wolfsburg              3.0
# 213  05-11-2023      Wolfsburg  2 - 2  Werder Bremen              2.0
# 214  10-11-2023    M''gladbach  4 - 0      Wolfsburg              4.0
# 215  25-11-2023      Wolfsburg  ? - ?     RB Leipzig              0.0
#
#      away_team_score
# 0                4.0
# 1                1.0
# 2                2.0
# 3                0.0
# ...

# %%
summary_data = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses':[]
}
summary_df = pd.DataFrame(summary_data)

teams = df1['home_team'].append(df1['away_team']).unique()
for team in teams:
    team_matches_home = df1[df1['home_team'] == team]
    team_matches_away = df1[df1['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])

    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df = summary_df.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws':draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df['Country']='Germany'
summary_df['League']='Bundesliga'
summary_df
# Out:
#              Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0        Augsburg          48.0            38.0            24.0  10.0   10.0
# 1   Bayern Munich          62.0            40.0            24.0  10.0    6.0
# 2      RB Leipzig          50.0            26.0            24.0  12.0    6.0
# 3        Freiburg          48.0            24.0            24.0  14.0    6.0
# 4      Heidenheim          54.0            32.0            24.0  16.0    4.0
# 5         FC Koln          40.0            24.0            24.0  10.0    8.0
# 6    Union Berlin          36.0            38.0            24.0  12.0    2.0
# 7   Werder Bremen          48.0            32.0            24.0  14.0    6.0
# 8     M''gladbach          46.0            46.0            24.0   6.0   10.0
# 9           Mainz          38.0            32.0            24.0   8.0   10.0
# 10       Dortmund          36.0            40.0            24.0  10.0    8.0
# ...

# %%
summary_df.to_csv('Bundesliga.csv', index=False)

# %%
df2=pd.read_csv("epl_match_data.csv")
df2[['home_team_score', 'away_team_score']] = df2['score'].str.split(' - ', expand=True)
df2['home_team_score'] = pd.to_numeric(df2['home_team_score'], errors='coerce')
df2['away_team_score'] = pd.to_numeric(df2['away_team_score'], errors='coerce')
df2['home_team_score'] = df2['home_team_score'].fillna(0)
df2['away_team_score'] = df2['away_team_score'].fillna(0)

summary_data2 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws':[],
    'Losses': []
}
summary_df2 = pd.DataFrame(summary_data2)

teams = df2['home_team'].append(df2['away_team']).unique()
for team in teams:
    team_matches_home = df2[df2['home_team'] == team]
    team_matches_away = df2[df2['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])

    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df2 = summary_df2.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws':draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df2['Country']='England'
summary_df2['League']='Premier League'
summary_df2
# Out:
#                 Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  \
# 0            Arsenal          42.0            30.0            26.0  12.0
# 1     Crystal Palace          28.0            28.0            26.0   6.0
# 2            Everton          32.0            30.0            26.0   6.0
# 3        Bournemouth          46.0            30.0            26.0  12.0
# 4            Chelsea          30.0            44.0            26.0   4.0
# 5          Newcastle          48.0            32.0            26.0  16.0
# 6          Brentford          38.0            34.0            26.0  10.0
# 7        Aston Villa          70.0            22.0            26.0  18.0
# 8            Burnley          32.0            46.0            26.0   8.0
# 9          Liverpool          50.0            24.0            26.0  14.0
# 10            Wolves          34.0            38.0            24.0  10.0
# 11     Nott'm Forest          42.0            22.0            26.0  14.0
# ...

# %%
df3 = pd.read_csv("laliga_match_data.csv")
df3[['home_team_score', 'away_team_score']] = df3['score'].str.split(' - ', expand=True)
df3['home_team_score'] = pd.to_numeric(df3['home_team_score'], errors='coerce')
df3['away_team_score'] = pd.to_numeric(df3['away_team_score'], errors='coerce')
df3['home_team_score'] = df3['home_team_score'].fillna(0)
df3['away_team_score'] = df3['away_team_score'].fillna(0)

summary_data3 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws':[],
    'Losses': []
}
summarydf3 = pd.DataFrame(summary_data3)

teams = df3['home_team'].append(df3['away_team']).unique()
for team in teams:
    team_matches_home = df3[df3['home_team'] == team]
    team_matches_away = df3[df3['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summarydf3 = summarydf3.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws':draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summarydf3['Country']='Spain'
summarydf3['League']='Laliga'
summarydf3
# Out:
#            Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0         Cadiz          38.0            16.0            26.0  14.0   10.0
# 1        Alaves          34.0            24.0            28.0  16.0    8.0
# 2        Getafe          40.0            24.0            28.0  12.0   16.0
# 3     Vallecano          22.0            42.0            28.0   4.0   14.0
# 4         Celta          34.0            42.0            28.0   8.0   10.0
# 5    Villarreal          40.0            44.0            28.0   6.0    8.0
# 6    Ath Madrid          42.0            40.0            26.0  16.0    4.0
# 7     Barcelona          46.0            32.0            28.0  12.0    8.0
# 8       Almeria          54.0            46.0            28.0  10.0    8.0
# 9       Sevilla          40.0            30.0            26.0   8.0   14.0
# 10   Ath Bilbao          48.0            36.0            26.0  12.0    6.0
# ...

# %%
df4 = pd.read_csv("ligue1_match_data.csv")
df4[['home_team_score', 'away_team_score']] = df4['score'].str.split(' - ', expand=True)
df4['home_team_score'] = pd.to_numeric(df4['home_team_score'], errors='coerce')
df4['away_team_score'] = pd.to_numeric(df4['away_team_score'], errors='coerce')
df4['home_team_score'] = df4['home_team_score'].fillna(0)
df4['away_team_score'] = df4['away_team_score'].fillna(0)

summary_data4 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws':[],
    'Losses': []
}
summarydf4 = pd.DataFrame(summary_data4)

teams = df4['home_team'].append(df4['away_team']).unique()
for team in teams:
    team_matches_home = df4[df4['home_team'] == team]
    team_matches_away = df4[df4['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summarydf4 = summarydf4.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws':draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summarydf4['Country']='France'
summarydf4['League']='League1'
summarydf4
# Out:
#            Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0         Brest          28.0            20.0            24.0  10.0    8.0
# 1      Le Havre          28.0            22.0            26.0   6.0   14.0
# 2     Marseille          38.0            12.0            24.0  14.0   10.0
# 3         Reims          28.0            36.0            26.0   8.0    6.0
# 4          Nice          18.0            16.0            26.0   6.0   12.0
# 5         Lille          32.0            20.0            26.0  10.0   12.0
# 6        Monaco          46.0            32.0            26.0  12.0    8.0
# 7   Montpellier          30.0            28.0            24.0   8.0   10.0
# 8      Clermont          20.0            24.0            24.0   6.0    8.0
# 9      Toulouse          36.0            22.0            26.0   8.0   14.0
# 10         Lyon          24.0            32.0            24.0   6.0   10.0
# ...

# %%
df5 = pd.read_csv("serieA_match_data.csv")
df5[['home_team_score', 'away_team_score']] = df5['score'].str.split(' - ', expand=True)
df5['home_team_score'] = pd.to_numeric(df5['home_team_score'], errors='coerce')
df5['away_team_score'] = pd.to_numeric(df5['away_team_score'], errors='coerce')
df5['home_team_score'] = df5['home_team_score'].fillna(0)
df5['away_team_score'] = df5['away_team_score'].fillna(0)

summary_data5 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df5 = pd.DataFrame(summary_data5)

teams = df5['home_team'].append(df5['away_team']).unique()
for team in teams:
    team_matches_home = df5[df5['home_team'] == team]
    team_matches_away = df5[df5['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df5 = summary_df5.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df5['Country']='Italy'
summary_df5['League']='SerieA'
summary_df5
# Out:
#            Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0      Sassuolo          40.0            34.0            26.0  10.0    8.0
# 1     Frosinone          46.0            28.0            26.0  16.0    8.0
# 2      Atalanta          34.0            28.0            26.0  12.0    6.0
# 3    Fiorentina          36.0            36.0            26.0  10.0    6.0
# 4        Verona          24.0            22.0            24.0  12.0    4.0
# 5         Lazio          32.0            20.0            26.0  14.0    6.0
# 6        Empoli          30.0            22.0            26.0  10.0    4.0
# 7       Udinese          20.0            26.0            26.0   2.0   18.0
# 8       Bologna          28.0            18.0            24.0  10.0   12.0
# 9      Juventus          28.0            24.0            26.0  12.0    6.0
# 10        Monza          32.0            16.0            26.0  10.0   12.0
# ...

# %%
df6 = pd.read_csv("Eredivisie_match_data.csv")
df6[['home_team_score', 'away_team_score']] = df6['score'].str.split(' - ', expand=True)
df6['home_team_score'] = pd.to_numeric(df6['home_team_score'], errors='coerce')
df6['away_team_score'] = pd.to_numeric(df6['away_team_score'], errors='coerce')
df6['home_team_score'] = df6['home_team_score'].fillna(0)
df6['away_team_score'] = df6['away_team_score'].fillna(0)

summary_data6 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df6 = pd.DataFrame(summary_data6)

teams = df6['home_team'].append(df6['away_team']).unique()
for team in teams:
    team_matches_home = df6[df6['home_team'] == team]
    team_matches_away = df6[df6['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df6 = summary_df6.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df6['Country']='Netherlands'
summary_df6['League']='Eredivisie'
summary_df6
# Out:
#                 Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  \
# 0         AZ Alkmaar          38.0            26.0            24.0  10.0
# 1           Waalwijk          28.0            28.0            24.0  12.0
# 2            Vitesse          32.0            34.0            26.0   8.0
# 3             Zwolle          36.0            34.0            26.0  10.0
# 4               Ajax          54.0            36.0            24.0  12.0
# 5          Excelsior          40.0            42.0            26.0   6.0
# 6          Feyenoord          52.0            38.0            26.0  12.0
# 7    Fortuna Sittard          46.0            18.0            26.0  14.0
# 8             Twente          36.0            36.0            26.0  12.0
# 9            Utrecht          32.0            36.0            26.0  10.0
# 10     PSV Eindhoven          50.0            50.0            26.0  14.0
# 11    Almere City FC          30.0            38.0            26.0   6.0
# ...

# %%
df7 = pd.read_csv("Russia_match_data.csv")
df7[['home_team_score', 'away_team_score']] = df7['score'].str.split(' - ', expand=True)
df7['home_team_score'] = pd.to_numeric(df7['home_team_score'], errors='coerce')
df7['away_team_score'] = pd.to_numeric(df7['away_team_score'], errors='coerce')
df7['home_team_score'] = df7['home_team_score'].fillna(0)
df7['away_team_score'] = df7['away_team_score'].fillna(0)

summary_data7 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df7 = pd.DataFrame(summary_data7)

teams = df7['home_team'].append(df7['away_team']).unique()
for team in teams:
    team_matches_home = df7[df7['home_team'] == team]
    team_matches_away = df7[df7['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df7 = summary_df7.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df7['Country']='Russia'
summary_df7['League']='Russian_Premier_League'
summary_df7
# Out:
#                    Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  \
# 0              FK SOCHI          50.0            32.0            32.0  18.0
# 1             Spartak M          54.0            32.0            32.0  20.0
# 2               Baltika          42.0            24.0            32.0  20.0
# 3         Dinamo Moscow          46.0            40.0            32.0  10.0
# 4         Krylya Samara          72.0            32.0            32.0  20.0
# 5           Lokomotiv M          40.0            40.0            32.0  10.0
# 6           CSKA Moscow          56.0            38.0            32.0  14.0
# 7           Rubin Kazan          28.0            42.0            32.0   8.0
# 8       Nizhny Novgorod          42.0            14.0            32.0  22.0
# 9                  Ural          42.0            36.0            32.0  12.0
# 10         Terek Grozny          42.0            30.0            32.0  12.0
# ...

# %%
df8 = pd.read_csv("SPL_match_data.csv")
df8[['home_team_score', 'away_team_score']] = df8['score'].str.split(' - ', expand=True)
df8['home_team_score'] = pd.to_numeric(df8['home_team_score'], errors='coerce')
df8['away_team_score'] = pd.to_numeric(df8['away_team_score'], errors='coerce')
df8['home_team_score'] = df8['home_team_score'].fillna(0)
df8['away_team_score'] = df8['away_team_score'].fillna(0)

summary_data8 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df8 = pd.DataFrame(summary_data8)

teams = df8['home_team'].append(df8['away_team']).unique()
for team in teams:
    team_matches_home = df8[df8['home_team'] == team]
    team_matches_away = df8[df8['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df8 = summary_df8.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df8['Country']='Scotland'
summary_df8['League']='SPL'
summary_df8
# Out:
#             Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0     Livingston          32.0            28.0            28.0  10.0   10.0
# 1       Aberdeen          40.0            28.0            24.0   8.0    8.0
# 2      St Mirren          42.0            30.0            26.0  10.0   10.0
# 3         Hearts          22.0            26.0            26.0  10.0    6.0
# 4        Rangers          26.0            38.0            26.0  10.0    2.0
# 5     Kilmarnock          40.0            20.0            28.0  16.0   10.0
# 6     Motherwell          36.0            36.0            28.0  10.0    8.0
# 7         Celtic          42.0            40.0            28.0  10.0    6.0
# 8      Hibernian          42.0            34.0            28.0   8.0   14.0
# 9    Ross County          34.0            30.0            26.0   8.0   10.0
# 10        Dundee          32.0            26.0            26.0  10.0   12.0
# ...

# %%
df9 = pd.read_csv("Turkey_match_data.csv")
df9[['home_team_score', 'away_team_score']] = df9['score'].str.split(' - ', expand=True)
df9['home_team_score'] = pd.to_numeric(df9['home_team_score'], errors='coerce')
df9['away_team_score'] = pd.to_numeric(df9['away_team_score'], errors='coerce')
df9['home_team_score'] = df9['home_team_score'].fillna(0)
df9['away_team_score'] = df9['away_team_score'].fillna(0)

summary_data9 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df9 = pd.DataFrame(summary_data9)

teams = df9['home_team'].append(df9['away_team']).unique()
for team in teams:
    team_matches_home = df9[df9['home_team'] == team]
    team_matches_away = df9[df9['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df9 = summary_df9.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df9['Country']='Turkey'
summary_df9['League']='Turkish Super Lig'
summary_df9
# Out:
#                 Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  \
# 0    Adana Demirspor          52.0            18.0            26.0  16.0
# 1         Ankaragucu          38.0            36.0            26.0  10.0
# 2          Hatayspor          38.0            34.0            26.0  10.0
# 3          Kasimpasa          40.0            48.0            26.0   8.0
# 4   Fatih Karagümrük          26.0            20.0            26.0   8.0
# 5          Sivasspor          28.0            32.0            26.0   4.0
# 6        Kayserispor          38.0            22.0            26.0  12.0
# 7         Alanyaspor          30.0            22.0            26.0  10.0
# 8           Rizespor          38.0            18.0            26.0  14.0
# 9         Pendikspor          32.0            48.0            26.0   6.0
# 10       Trabzonspor          40.0            30.0            26.0  16.0
# 11       Galatasaray          30.0            30.0            26.0  12.0
# ...

# %%
df10 = pd.read_csv("portugal_match_data.csv")
df10[['home_team_score', 'away_team_score']] = df10['score'].str.split(' - ', expand=True)
df10['home_team_score'] = pd.to_numeric(df10['home_team_score'], errors='coerce')
df10['away_team_score'] = pd.to_numeric(df10['away_team_score'], errors='coerce')
df10['home_team_score'] = df10['home_team_score'].fillna(0)
df10['away_team_score'] = df10['away_team_score'].fillna(0)

summary_data10 = {
    'Team': [],
    'Goals_Scored': [],
    'Goals_Conceded': [],
    'Matches_Played': [],
    'Wins': [],
    'Draws': [],
    'Losses': []
}
summary_df10 = pd.DataFrame(summary_data10)

teams = df10['home_team'].append(df10['away_team']).unique()
for team in teams:
    team_matches_home = df10[df10['home_team'] == team]
    team_matches_away = df10[df10['away_team'] == team]
    team_matches = pd.concat([team_matches_home, team_matches_away])

    goals_scored = team_matches['home_team_score'].sum()
    goals_conceded = team_matches['away_team_score'].sum()
    matches_played = len(team_matches)
    wins = len(team_matches[team_matches['home_team_score'] > team_matches['away_team_score']])
    draws = len(team_matches[team_matches['home_team_score'] == team_matches['away_team_score']])
    losses = len(team_matches[team_matches['home_team_score'] < team_matches['away_team_score']])

    summary_df10 = summary_df10.append({
        'Team': team,
        'Goals_Scored': goals_scored,
        'Goals_Conceded': goals_conceded,
        'Matches_Played': matches_played,
        'Wins': wins,
        'Draws': draws,
        'Losses': losses
    }, ignore_index=True)

# %%
summary_df10['Country']='Portugal'
summary_df10['League']='Portugese Liga Nos'
summary_df10
# Out:
#                Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  \
# 0            Arouca          26.0            26.0            22.0   8.0
# 1            Vizela          26.0            28.0            22.0   6.0
# 2             Porto          20.0            26.0            22.0   8.0
# 3      FC Famalicão          24.0            18.0            22.0  10.0
# 4         Sp Lisbon          40.0            28.0            22.0  14.0
# 5           Farense          40.0            30.0            22.0  12.0
# 6          Boavista          40.0            38.0            22.0   8.0
# 7           Benfica          34.0            30.0            22.0  10.0
# 8       Gil Vicente          60.0            30.0            22.0  16.0
# 9   Portimonense SC          44.0            32.0            22.0  10.0
# 10          Estoril          48.0            30.0            22.0  14.0
# 11           Chaves          54.0            32.0            22.0  12.0
# ...

# %%
Final_df=pd.concat([summary_df,summary_df2,summarydf3,summarydf4,summary_df5,summary_df6,summary_df7,summary_df8,summary_df9,summary_df10])

# %%
Final_df
# Out:
#              Team  Goals_Scored  Goals_Conceded  Matches_Played  Wins  Draws  \
# 0        Augsburg          48.0            38.0            24.0  10.0   10.0
# 1   Bayern Munich          62.0            40.0            24.0  10.0    6.0
# 2      RB Leipzig          50.0            26.0            24.0  12.0    6.0
# 3        Freiburg          48.0            24.0            24.0  14.0    6.0
# 4      Heidenheim          54.0            32.0            24.0  16.0    4.0
# ..            ...           ...             ...             ...   ...    ...
# 13     Moreirense          20.0            28.0            22.0   6.0    4.0
# 14        Rio Ave          34.0            28.0            22.0  10.0    6.0
# 15       Casa Pia          20.0            22.0            22.0   4.0    8.0
# 16      Guimaraes          40.0            22.0            22.0  12.0    2.0
# 17        Estrela          26.0            28.0            22.0   8.0    4.0
#
#     Losses   Country              League
# ...

# %%
Final_df.to_csv('Europe_top_5_league.csv', index=False)
